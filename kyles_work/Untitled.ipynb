# %%
import pandas as pd
import os

# %%
pd.read_csv('daily01.csv')
# Out:
#       Unnamed: 0  index  Unnamed: 0.1               id  \
# 0              0      0        271320  TRN_ARB_0267047
# 1              1      1        271321  TRN_ARB_0267051
# 2              2      2        271322  TRN_ARB_0267057
# 3              3      3        271323  TRN_ARB_0267064
# 4              4      4        271324  TRN_ARB_0267091
# ...          ...    ...           ...              ...
# 3565        3565    352        226333  SYM_ARB_0621712
# 3566        3566    353        226334  SYM_ARB_0621716
# 3567        3567    354        226335  SYM_ARB_0621718
# 3568        3568    355        226336  SYM_ARB_0621760
# 3569        3569    356        226337  SYM_ARB_0621761
#
#                                                     url  \
# 0     http://tishreen.news.sy/tishreen/public/read/2...
# 1     http://tishreen.news.sy/tishreen/public/read/2...
# 2     http://tishreen.news.sy/tishreen/public/read/2...
# 3     http://tishreen.news.sy/tishreen/public/read/2...
# 4     http://tishreen.news.sy/tishreen/public/read/2...
# ...                                                 ...
# 3565  http://www.alyaum.com/oldsite/issue/article.ph...
# 3566  http://www.alyaum.com/oldsite/issue/article.ph...
# 3567  http://www.alyaum.com/oldsite/issue/article.ph...
# 3568  http://www.alyaum.com/oldsite/issue/article.ph...
# 3569  http://www.alyaum.com/oldsite/issue/article.ph...
#
#                                                headline  \
# 0                بندر بن سلطان.. اليد الشيطانية السوداء
# 1     صدق أو لا تصدق.. الولايات المتحدة تخطط لشرق أو...
# 2                    الإرهاب الإعلامي... وحصاد الخائبين
# 3                                 بيزوني ينفي فسخ عقـده
# 4                   وقف الحرب الإرهابية الأولوية والهدف
# ...                                                 ...
# 3565  تشيني يبحث التعاون مع جيران روسيا ومساعدة أمري...
# 3566    نجاة رئيس الوزراء الباكسـتاني من محـاولة اغتيال
# 3567       مقتل 6 من الأمن العراقي بنيران صديقة أمريكية
# 3568                       في جورجيا لا رصـاص ولا سـلام
# 3569                        بيونجيانج وطريقتها المعتادة
#
#                                                dateline  \
# 0                                            10/09/2012
# 1                                            10/09/2012
# 2                                            10/09/2012
# 3                                            10/09/2012
# 4                                            10/09/2012
# ...                                                 ...
# 3565  الخميس 1429-09-04 هـ الموافق 2008-09-04 م\nرئي...
# 3566  الخميس 1429-09-04 هـ الموافق 2008-09-04 م\nسيا...
# 3567  الخميس 1429-09-04 هـ الموافق 2008-09-04 م\nطفل...
# 3568          الجمعة 1429-09-05 هـ الموافق 2008-09-05 م
# 3569          الجمعة 1429-09-05 هـ الموافق 2008-09-05 م
#
#                                                    text  \
# 0     \n10/09/2012\nوجهان لا يتقابلان ولا يلتقيان .....
# 1     \n10/09/2012\nموقع: أرض بلا عنف\nصدق أو لا تصد...
# 2     \n10/09/2012\nبالخط العريض\nالإرهاب الإعلامي.....
# 3     \n10/09/2012\nبيزوني ينفي فسخ عقـده\nنفى اللاع...
# 4     \n10/09/2012\nاليوم وغداً\nوقف الحرب الإرهابية...
# ...                                                 ...
# 3565  اعتبر نائب الرئيس الامريكي ديك تشيني، أمس في ا...
# 3566  نجا رئيس الوزراء الباكستاني يوسف رضا جيلاني، م...
# 3567  قال الجيش الأمريكي ومصادر أمنية عراقية ان قوات...
# 3568  بعد مرور ثلاثة اسابيع تقريبا على غزو روسيا جار...
# 3569  اعلنت كوريا الشمالية الاسبوع الماضي انها ستتوق...
#
#                                        tags     source text_label  \
# 0     ['واشنطن', 'بوش', 'تشيني', 'القاعدة']   Techreen   negative
# 1                                ['واشنطن']   Techreen      False
# 2                                ['أمريكا']   Techreen   negative
# 3                                ['فيسبوك']   Techreen    neutral
# 4                               ['القاعدة']   Techreen      False
# ...                                     ...        ...        ...
# 3565             ['واشنطن', 'بوش', 'تشيني']  SaudiYoum      False
# 3566                            ['القاعدة']  SaudiYoum    neutral
# 3567                            ['القاعدة']  SaudiYoum    neutral
# 3568             ['واشنطن', 'بوش', 'تشيني']  SaudiYoum   negative
# 3569                      ['واشنطن', 'بوش']  SaudiYoum   negative
#
#               text_score headline_label  headline_score
# 0     0.9679330388704935       negative        0.996143
# 1                  False       negative        0.964706
# 2     0.9948807954788208       negative        0.992690
# 3     0.8556976914405823        neutral        0.970813
# 4                  False        neutral        0.773544
# ...                  ...            ...             ...
# 3565               False        neutral        0.996266
# 3566  0.9479027986526489        neutral        0.652550
# 3567  0.6887681484222412        neutral        0.608006
# 3568  0.9686555862426758       negative        0.784216
# 3569  0.6822898387908936        neutral        0.987450
#
# [3570 rows x 14 columns]

# %%
df = pd.read_csv('/Users/kylegreen/My Drive/arabic_NLP/daily08_01.csv')

# %%
df.text_label.value_counts()
# Out:
# neutral     8477
# False       4830
# negative    2932
# positive     540
# Name: text_label, dtype: int64

# %%
df = pd.read_csv('all_articles.csv')

# %%
df.head()
# Out:
#                 id                                                url  \
# 0  ETD_ARB_0000033  http://www.alittihad.ae/details.php?id=53&y=20...
# 1  ETD_ARB_0000035  http://www.alittihad.ae/details.php?id=55&y=20...
# 2  ETD_ARB_0000036  http://www.alittihad.ae/details.php?id=56&y=20...
# 3  ETD_ARB_0000062  http://www.alittihad.ae/details.php?id=82&y=20...
# 4  ETD_ARB_0000065  http://www.alittihad.ae/details.php?id=85&y=20...
#
#                                             headline  \
# 0  الوثائق الرئاسية الأميركية··· متجاهلو التاريخ ...
# 1                                   التنبؤات السنوية
# 2  شلهوب والحاسوب ·· يقدم وجبة تعليمية وفكرية ممت...
# 3       48 قتيلاً وجريحاً باعتداءات متفرقة في العراق
# 4  النفط فوق 100 دولار·· هيلاري رئيسة لأميركا·· ا...
#
#                               dateline  \
# 0  تاريخ النشر: الثلاثاء 01 يناير 2008
# 1  تاريخ النشر: الثلاثاء 01 يناير 2008
# 2  تاريخ النشر: الثلاثاء 01 يناير 2008
# 3  تاريخ النشر: الثلاثاء 01 يناير 2008
# 4  تاريخ النشر: الثلاثاء 01 يناير 2008
#
#                                                 text                   tags  \
# 0  ربما نسي الكثيرون الآن الأمر التنفيذي الخاص با...      ['واشنطن', 'بوش']
# 1  هذه هي حلقة التنبؤات المشتركة السنوية الرابعة ...  ['أوباما', 'كلينتون']
# 2  ''''كم هو جميل، هذا العالم السحري عالم الأطفال...                ['بوش']
# 3  في استهداف جديد لعناصر ''''صحوة'''' العشائر ال...            ['القاعدة']
# 4  استقبل العالم أول أيام العام الجديد ،2008 باحت...            ['كلينتون']
#
#       source
# 0  Alittihad
# 1  Alittihad
# 2  Alittihad
# 3  Alittihad
# 4  Alittihad

# %%
df.shape
# Out:
# (357767, 7)

# %%
import regex as re
import pandas as pd
import numpy as np

def find_month(df_dateline):
    exp = '\d\d.*\d\d\d\d'
    try:
        month = re.search(exp, df_dateline).group()[2:-4]
        months = {'January' : 'يناير',
                        'February' : 'فبراير',
                        'March' : 'مارس',
                        'April' : 'أبريل',
                        'June' : 'يوني',
                        'July' : 'يولي',
                        'August' : 'أغسطس',
                        'September' : 'سبتمبر',
                        'October' : 'أكتوبر',
                        'November' : 'نوفمبر',
                        'December' : 'ديسمبر',
                        'April1' : 'إبريل',
                        'May': 'ماي'}
    
        months = flip_key_value_pairs(months)
        
        return re.search(exp, df_dateline).group()[2:-4]
    except:
        
        try:
            return re.search('20\d\d\W\d\d\W\d\d', val).group()

        except:
            return False

def flip_key_value_pairs(dicts):
    res = dict((v,k) for k,v in dicts.items())
    return res

my_array = [True if val else False for val in df.dateline.apply(find_month)]

print(sum(my_array))
print(len(my_array))

df[np.array(my_array)]
# Out:
# 273916
# 357767
#                      id                                                url  \
# 0       ETD_ARB_0000033  http://www.alittihad.ae/details.php?id=53&y=20...
# 1       ETD_ARB_0000035  http://www.alittihad.ae/details.php?id=55&y=20...
# 2       ETD_ARB_0000036  http://www.alittihad.ae/details.php?id=56&y=20...
# 3       ETD_ARB_0000062  http://www.alittihad.ae/details.php?id=82&y=20...
# 4       ETD_ARB_0000065  http://www.alittihad.ae/details.php?id=85&y=20...
# ...                 ...                                                ...
# 357762  YM7_ARB_1024957      http://www1.youm7.com/News.asp?NewsID=1064004
# 357763  YM7_ARB_1024974      http://www1.youm7.com/News.asp?NewsID=1064021
# 357764  YM7_ARB_1024978      http://www1.youm7.com/News.asp?NewsID=1064025
# 357765  YM7_ARB_1025001      http://www1.youm7.com/News.asp?NewsID=1064048
# 357766  YM7_ARB_1025006      http://www1.youm7.com/News.asp?NewsID=1064053
#
#                                                  headline  \
# 0       الوثائق الرئاسية الأميركية··· متجاهلو التاريخ ...
# 1                                        التنبؤات السنوية
# 2       شلهوب والحاسوب ·· يقدم وجبة تعليمية وفكرية ممت...
# 3            48 قتيلاً وجريحاً باعتداءات متفرقة في العراق
# 4       النفط فوق 100 دولار·· هيلاري رئيسة لأميركا·· ا...
# ...                                                   ...
# 357762  وزير الدفاع الفرنسى يناقش الأوضاع فى ليبيا خلا...
# 357763  الخارجية الأمريكية: احتمال تأجيل عقد المؤتمر ا...
# 357764       مقتل ثلاثة جنود جورجيين فى هجوم فى أفغانستان
# 357765  الفلسطينيون يتحدون وراء نجم من قطاع غزة يشارك ...
# 357766  أبو إسماعيل ينفى وصفه لوزير الدفاع بأنه ممثل ع...
#
#                                    dateline  \
# 0       تاريخ النشر: الثلاثاء 01 يناير 2008
# 1       تاريخ النشر: الثلاثاء 01 يناير 2008
# 2       تاريخ النشر: الثلاثاء 01 يناير 2008
# 3       تاريخ النشر: الثلاثاء 01 يناير 2008
# 4       تاريخ النشر: الثلاثاء 01 يناير 2008
# ...                                     ...
# 357762        الإثنين، 13 مايو 2013 - 22:20
# 357763        الإثنين، 13 مايو 2013 - 22:34
# 357764        الإثنين، 13 مايو 2013 - 22:37
# 357765        الإثنين، 13 مايو 2013 - 22:55
# 357766        الإثنين، 13 مايو 2013 - 23:00
#
#                                                      text  \
# 0       ربما نسي الكثيرون الآن الأمر التنفيذي الخاص با...
# 1       هذه هي حلقة التنبؤات المشتركة السنوية الرابعة ...
# 2       ''''كم هو جميل، هذا العالم السحري عالم الأطفال...
# 3       في استهداف جديد لعناصر ''''صحوة'''' العشائر ال...
# 4       استقبل العالم أول أيام العام الجديد ،2008 باحت...
# ...                                                   ...
# 357762  أعلن وزير الدفاع الفرنسى، أن الجماعات الإرهابي...
# 357763  قالت المتحدثة باسم الخارجية الأمريكية، جينفر ب...
# 357764  قتل ثلاثة جنود جورجيين –الاثنين- فى هجوم انتحا...
# 357765  وجدت الفصائل المتناحرة فى قطاع غزة وأنحاء الأر...
# 357766  نفى حازم صلاح أبو إسماعيل، مؤسس حزب الراية، ذك...
#
#                          tags     source
# 0           ['واشنطن', 'بوش']  Alittihad
# 1       ['أوباما', 'كلينتون']  Alittihad
# 2                     ['بوش']  Alittihad
# 3                 ['القاعدة']  Alittihad
# 4                 ['كلينتون']  Alittihad
# ...                       ...        ...
# 357762  ['واشنطن', 'القاعدة']      Youm7
# 357763   ['واشنطن', 'أوباما']      Youm7
# 357764            ['القاعدة']      Youm7
# 357765   ['أمريكا', 'فيسبوك']      Youm7
# 357766             ['أمريكا']      Youm7
#
# [273916 rows x 7 columns]

# %%
df.dateline
# Out:
# 0         تاريخ النشر: الثلاثاء 01 يناير 2008
# 1         تاريخ النشر: الثلاثاء 01 يناير 2008
# 2         تاريخ النشر: الثلاثاء 01 يناير 2008
# 3         تاريخ النشر: الثلاثاء 01 يناير 2008
# 4         تاريخ النشر: الثلاثاء 01 يناير 2008
#                          ...
# 357762          الإثنين، 13 مايو 2013 - 22:20
# 357763          الإثنين، 13 مايو 2013 - 22:34
# 357764          الإثنين، 13 مايو 2013 - 22:37
# 357765          الإثنين، 13 مايو 2013 - 22:55
# 357766          الإثنين، 13 مايو 2013 - 23:00
# Name: dateline, Length: 357767, dtype: object
