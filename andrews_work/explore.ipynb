# %%
import pandas as pd
import date_fixer
import matplotlib.pyplot as plt
import seaborn as sns
df = pd.read_csv('daily8_3.csv')

# %%
df['dateline'] = pd.to_datetime(df['dateline'])
new = df

# %% [markdown]
# # Exploring Datetime

# %%
plt.figure(figsize = (18, 10))
sns.histplot(data=new, x='dateline', hue= 'source', bins=50)
# Out:
# <AxesSubplot:xlabel='dateline', ylabel='Count'>

# %%
sns.histplot(data=new, x='dateline', )
# Out:
# <AxesSubplot:xlabel='dateline', ylabel='Count'>

# %%
plt.figure(figsize = (18, 12))
sns.displot(data=new, x='dateline', col= 'source', bins=50)

# %% [markdown]
# # Exploring headline and text labels

# %%
plt.figure(figsize = (18, 12))
sns.displot(data=new, x='headline_label')

# %%
plt.figure(figsize = (18, 12))
sns.displot(data=new, x='headline_label', col= 'source')

# %%
new.headline_label.value_counts()
# Out:
# neutral     16418
# negative     5356
# positive     1750
# Name: headline_label, dtype: int64

# %%
plt.figure(figsize = (18, 12))
sns.displot(data=new, x='text_label')

# %%
plt.figure(figsize = (18, 12))
sns.displot(data=new, x='text_label', col= 'source')

# %%
no_false = new[new.text_label != 'False']

# %%
plt.figure(figsize = (18, 12))
sns.displot(data=no_false, x='text_label')

# %%
plt.figure(figsize = (18, 12))
sns.displot(data=no_false, x='text_label', col= 'source')

# %%
label_map ={'neutral':0,
           'positive':1,
           'negative':-1}
no_false.text_label.map(label_map)
# Out:
# 0        0
# 2        0
# 3       -1
# 4       -1
# 7        1
#         ..
# 23556    0
# 23557    0
# 23559    0
# 23560    0
# 23561    0
# Name: text_label, Length: 16979, dtype: int64

# %%
no_false
# Out:
#        index  Unnamed: 0               id  \
# 0          0      274890  TRN_ARB_0297955
# 2          2      274892  TRN_ARB_0297958
# 3          3      274893  TRN_ARB_0297960
# 4          4      274894  TRN_ARB_0297984
# 7          7      274897  TRN_ARB_0298010
# ...      ...         ...              ...
# 23556    351      121731  QBS_ARB_0250036
# 23557    352      121732  QBS_ARB_0250040
# 23559    354      121734  QBS_ARB_0250059
# 23560    355      121735  QBS_ARB_0250084
# 23561    356      121736  QBS_ARB_0250090
#
#                                                      url  \
# 0      http://tishreen.news.sy/tishreen/public/read/2...
# 2      http://tishreen.news.sy/tishreen/public/read/2...
# 3      http://tishreen.news.sy/tishreen/public/read/2...
# 4      http://tishreen.news.sy/tishreen/public/read/2...
# 7      http://tishreen.news.sy/tishreen/public/read/2...
# ...                                                  ...
# 23556             http://www.alqabas.com.kw/print/263733
# 23557             http://www.alqabas.com.kw/print/263738
# 23559             http://www.alqabas.com.kw/print/263757
# 23560             http://www.alqabas.com.kw/print/263784
# 23561             http://www.alqabas.com.kw/print/263792
#
#                                                 headline   dateline  \
# 0      وزير الخارجية الصيني: سنقوم بدور بنّاء وإيجابي... 2013-09-20
# 2      وزير الخارجية الإيراني: انضمام سورية لمعاهدة ح... 2013-09-20
# 3      استمرار أمريكا وحلفائها بدعم وتسليح الإرهابيين... 2013-09-20
# 4      المفاوض الفلسطيني.. والسباحة من جديد في بحر ال... 2013-09-22
# 7      المهندسة فهمية عروس: بالحوار نصـل بسـورية إلى ... 2013-09-22
# ...                                                  ...        ...
# 23556                       «القاعدة» يتبنّى هجمات العيد 2012-10-29
# 23557  بوتفليقة يبحث مع كلينتون تعزيز الشراكة الاقتصا... 2012-10-29
# 23559  العودة يدعو إلى الامتناع عن السفر إلى سوريا لل... 2012-10-29
# 23560              ميامي وليكرز أبرز المرشحين لنيل اللقب 2012-10-29
# 23561           اوباما يحذر مواطنيه من خطر الاعصار ساندي 2012-10-29
#
#                                                     text  \
# 0      \n20/09/2013\nوزير الخارجية الصيني: سنقوم بدور...
# 2      \n20/09/2013\nوزير الخارجية الإيراني: انضمام س...
# 3      \n20/09/2013\n«الخارجية» في رسالتين إلى رئيس م...
# 4      \n22/09/2013\nالمفاوض الفلسطيني.. والسباحة من ...
# 7      \n22/09/2013\nالمهندسة فهمية عروس: بالحوار نصـ...
# ...                                                  ...
# 23556  بغداد - وكالات - أعلنت امس ان قوات الامن العرا...
# 23557  (كونا) -- بحث الرئيس الجزائري عبدالعزيز بوتفلي...
# 23559  الرياض - يو بي آي - دعا عالم الدين السعودي، ال...
# 23560  واشنطن - أ ف ب - يشهد الموسم المقبل من الدوري ...
# 23561  (ا ف ب) - حذر الرئيس باراك اوباما الاثنين مواط...
#
#                                   tags    source text_label  \
# 0                           ['واشنطن']  Techreen    neutral
# 2                           ['واشنطن']  Techreen    neutral
# 3                ['أمريكا', 'القاعدة']  Techreen   negative
# 4                           ['واشنطن']  Techreen   negative
# 7                           ['أمريكا']  Techreen   positive
# ...                                ...       ...        ...
# 23556                      ['القاعدة']   Alqabas    neutral
# 23557  ['أمريكا', 'واشنطن', 'كلينتون']   Alqabas    neutral
# 23559                      ['القاعدة']   Alqabas    neutral
# 23560                ['واشنطن', 'بوش']   Alqabas    neutral
# 23561                       ['واشنطن']   Alqabas    neutral
#
#                text_score headline_label  headline_score
# 0      0.9574713706970215        neutral        0.538953
# 2      0.5859406590461731        neutral        0.774108
# 3      0.9461716612180074       negative        0.957832
# 4      0.9543005029360453       negative        0.954988
# 7      0.7322584191958109       positive        0.684957
# ...                   ...            ...             ...
# 23556  0.8499836921691895       negative        0.498749
# 23557   0.990750253200531        neutral        0.994249
# 23559  0.6828629374504089        neutral        0.902794
# 23560  0.9449390172958374        neutral        0.904816
# 23561  0.9412329792976379        neutral        0.825468
#
# [16979 rows x 13 columns]

# %%
label_map ={'neutral':0,
           'positive':1,
           'negative':-1}
no_false['text_label_as_int'] = no_false.text_label.map(label_map)
no_false['headline_label_as_int'] = no_false.headline_label.map(label_map)
# Out:
# /var/folders/r6/g880v64s6vj401drwcc37nf00000gn/T/ipykernel_43830/4075521369.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   no_false['text_label_as_int'] = no_false.text_label.map(label_map)
# /var/folders/r6/g880v64s6vj401drwcc37nf00000gn/T/ipykernel_43830/4075521369.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   no_false['headline_label_as_int'] = no_false.headline_label.map(label_map)

# %%
no_false
# Out:
#        index  Unnamed: 0               id  \
# 0          0      274890  TRN_ARB_0297955
# 2          2      274892  TRN_ARB_0297958
# 3          3      274893  TRN_ARB_0297960
# 4          4      274894  TRN_ARB_0297984
# 7          7      274897  TRN_ARB_0298010
# ...      ...         ...              ...
# 23556    351      121731  QBS_ARB_0250036
# 23557    352      121732  QBS_ARB_0250040
# 23559    354      121734  QBS_ARB_0250059
# 23560    355      121735  QBS_ARB_0250084
# 23561    356      121736  QBS_ARB_0250090
#
#                                                      url  \
# 0      http://tishreen.news.sy/tishreen/public/read/2...
# 2      http://tishreen.news.sy/tishreen/public/read/2...
# 3      http://tishreen.news.sy/tishreen/public/read/2...
# 4      http://tishreen.news.sy/tishreen/public/read/2...
# 7      http://tishreen.news.sy/tishreen/public/read/2...
# ...                                                  ...
# 23556             http://www.alqabas.com.kw/print/263733
# 23557             http://www.alqabas.com.kw/print/263738
# 23559             http://www.alqabas.com.kw/print/263757
# 23560             http://www.alqabas.com.kw/print/263784
# 23561             http://www.alqabas.com.kw/print/263792
#
#                                                 headline   dateline  \
# 0      وزير الخارجية الصيني: سنقوم بدور بنّاء وإيجابي... 2013-09-20
# 2      وزير الخارجية الإيراني: انضمام سورية لمعاهدة ح... 2013-09-20
# 3      استمرار أمريكا وحلفائها بدعم وتسليح الإرهابيين... 2013-09-20
# 4      المفاوض الفلسطيني.. والسباحة من جديد في بحر ال... 2013-09-22
# 7      المهندسة فهمية عروس: بالحوار نصـل بسـورية إلى ... 2013-09-22
# ...                                                  ...        ...
# 23556                       «القاعدة» يتبنّى هجمات العيد 2012-10-29
# 23557  بوتفليقة يبحث مع كلينتون تعزيز الشراكة الاقتصا... 2012-10-29
# 23559  العودة يدعو إلى الامتناع عن السفر إلى سوريا لل... 2012-10-29
# 23560              ميامي وليكرز أبرز المرشحين لنيل اللقب 2012-10-29
# 23561           اوباما يحذر مواطنيه من خطر الاعصار ساندي 2012-10-29
#
#                                                     text  \
# 0      \n20/09/2013\nوزير الخارجية الصيني: سنقوم بدور...
# 2      \n20/09/2013\nوزير الخارجية الإيراني: انضمام س...
# 3      \n20/09/2013\n«الخارجية» في رسالتين إلى رئيس م...
# 4      \n22/09/2013\nالمفاوض الفلسطيني.. والسباحة من ...
# 7      \n22/09/2013\nالمهندسة فهمية عروس: بالحوار نصـ...
# ...                                                  ...
# 23556  بغداد - وكالات - أعلنت امس ان قوات الامن العرا...
# 23557  (كونا) -- بحث الرئيس الجزائري عبدالعزيز بوتفلي...
# 23559  الرياض - يو بي آي - دعا عالم الدين السعودي، ال...
# 23560  واشنطن - أ ف ب - يشهد الموسم المقبل من الدوري ...
# 23561  (ا ف ب) - حذر الرئيس باراك اوباما الاثنين مواط...
#
#                                   tags    source text_label  \
# 0                           ['واشنطن']  Techreen    neutral
# 2                           ['واشنطن']  Techreen    neutral
# 3                ['أمريكا', 'القاعدة']  Techreen   negative
# 4                           ['واشنطن']  Techreen   negative
# 7                           ['أمريكا']  Techreen   positive
# ...                                ...       ...        ...
# 23556                      ['القاعدة']   Alqabas    neutral
# 23557  ['أمريكا', 'واشنطن', 'كلينتون']   Alqabas    neutral
# 23559                      ['القاعدة']   Alqabas    neutral
# 23560                ['واشنطن', 'بوش']   Alqabas    neutral
# 23561                       ['واشنطن']   Alqabas    neutral
#
#                text_score headline_label  headline_score  text_label_as_int  \
# 0      0.9574713706970215        neutral        0.538953                  0
# 2      0.5859406590461731        neutral        0.774108                  0
# 3      0.9461716612180074       negative        0.957832                 -1
# 4      0.9543005029360453       negative        0.954988                 -1
# 7      0.7322584191958109       positive        0.684957                  1
# ...                   ...            ...             ...                ...
# 23556  0.8499836921691895       negative        0.498749                  0
# 23557   0.990750253200531        neutral        0.994249                  0
# 23559  0.6828629374504089        neutral        0.902794                  0
# 23560  0.9449390172958374        neutral        0.904816                  0
# 23561  0.9412329792976379        neutral        0.825468                  0
#
#        headline_label_as_int
# 0                          0
# 2                          0
# 3                         -1
# 4                         -1
# 7                          1
# ...                      ...
# 23556                     -1
# 23557                      0
# 23559                      0
# 23560                      0
# 23561                      0
#
# [16979 rows x 15 columns]

# %%
def encode_sentiment(df, columns_to_encode):
    '''
    This function takes in a prepared dataframe and using one-hot encoding, encodes categorical variables. It does not drop the original
    categorical columns. This is done purposefully to allow for easier Exploratory Data Analysis.  Removal of original categorical columns
    will be done in a separate function later if desired.
    Arguments: df - a prepared dataframe with the expected feature names and columns
    Returns: encoded - a dataframe with all desired categorical columns encoded.
    '''
    dummies_list = columns_to_encode

    dummy_df = pd.get_dummies(df[dummies_list], drop_first=False)
    encoded = pd.concat([df, dummy_df], axis = 1)
    return encoded

# %%
encoded = encode_sentiment(df, ['text_label'])

# %%
encoded.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 16979 entries, 0 to 23561
# Data columns (total 18 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   index                  16979 non-null  int64
#  1   Unnamed: 0             16979 non-null  int64
#  2   id                     16979 non-null  object
#  3   url                    16979 non-null  object
#  4   headline               16979 non-null  object
#  5   dateline               16979 non-null  datetime64[ns]
#  6   text                   16979 non-null  object
#  7   tags                   16979 non-null  object
#  8   source                 16979 non-null  object
#  9   text_label             16979 non-null  object
#  10  text_score             16979 non-null  object
#  11  headline_label         16979 non-null  object
#  12  headline_score         16979 non-null  float64
#  13  text_label_as_int      16979 non-null  int64
#  14  headline_label_as_int  16979 non-null  int64
#  15  text_label_negative    16979 non-null  uint8
#  16  text_label_neutral     16979 non-null  uint8
#  17  text_label_positive    16979 non-null  uint8
# dtypes: datetime64[ns](1), float64(1), int64(4), object(9), uint8(3)
# memory usage: 2.6+ MB

# %%
encoded = encoded[encoded.text_label != 'False']

# %%
label_map ={'neutral':0,
           'positive':1,
           'negative':-1}
encoded.text_label.map(label_map)
# Out:
# 0        0
# 2        0
# 3       -1
# 4       -1
# 7        1
#         ..
# 23556    0
# 23557    0
# 23559    0
# 23560    0
# 23561    0
# Name: text_label, Length: 16979, dtype: int64

# %%
encoded.text_label.value_counts()
# Out:
# neutral     12309
# negative     3971
# positive      699
# Name: text_label, dtype: int64

# %%
encoded.text_label_negative.value_counts()
# Out:
# 0    13008
# 1     3971
# Name: text_label_negative, dtype: int64

# %%
encoded.set_index('dateline').sort_index()
# Out:
#             index  Unnamed: 0               id  \
# dateline
# 2002-07-01    293      189146  SYM_ARB_0002704
# 2002-07-01    288      189141  SYM_ARB_0002614
# 2002-07-01    290      189143  SYM_ARB_0002644
# 2002-07-01    292      189145  SYM_ARB_0002684
# 2002-07-01    295      189148  SYM_ARB_0002732
# ...           ...         ...              ...
# 2014-05-26     84      188937  SBN_ARB_0092108
# 2014-05-26     83      188936  SBN_ARB_0092107
# 2014-05-26     82      188935  SBN_ARB_0092094
# 2014-05-26     79      188932  SBN_ARB_0092053
# 2014-05-26     81      188934  SBN_ARB_0092078
#
#                                                           url  \
# dateline
# 2002-07-01  http://www.alyaum.com/oldsite/issue/article.ph...
# 2002-07-01  http://www.alyaum.com/oldsite/issue/article.ph...
# 2002-07-01  http://www.alyaum.com/oldsite/issue/article.ph...
# 2002-07-01  http://www.alyaum.com/oldsite/issue/article.ph...
# 2002-07-01  http://www.alyaum.com/oldsite/issue/article.ph...
# ...                                                       ...
# 2014-05-26          http://www.sabanews.net/ar/news354901.htm
# 2014-05-26          http://www.sabanews.net/ar/news354899.htm
# 2014-05-26          http://www.sabanews.net/ar/news354885.htm
# 2014-05-26          http://www.sabanews.net/ar/news354841.htm
# 2014-05-26          http://www.sabanews.net/ar/news354868.htm
#
#                                                      headline  \
# dateline
# 2002-07-01  نائب خادم الحرمين الشريفين يستقبل عضوا في الكو...
# 2002-07-01                                        شروط العقار
# 2002-07-01                 ""بالاديوم"" لتحسين الأمن الحاسوبي
# 2002-07-01   رونالدو يقود السامبا للتحليق بكأس العالم الخامسة
# 2002-07-01  أمريكا تجري مشاورات مع الأصدقاء العرب لدفع عمل...
# ...                                                       ...
# 2014-05-26  وزير الداخلية يناقش مع قيادة محافظة صنعاء الأو...
# 2014-05-26  محافظ أبين يشيد بإنجاز فريق فحمان وصعوده للدور...
# 2014-05-26  افتتاح وتأسيس مشاريع تنموية وخدمية بأبين بتكلف...
# 2014-05-26  سيرينا تحتفظ بصدارة التصنيف العالمي للاعبات التنس
# 2014-05-26  مديريتا الوحدة والسبعين بأمانة العاصمة تحتفيان...
#
#                                                          text         tags  \
# dateline
# 2002-07-01  استقبل صاحب السمو الملكي الامير عبدالله بن عبد...   ['واشنطن']
# 2002-07-01  لايزال الاستثمار العقاري يعد من القنوات الاستث...  ['القاعدة']
# 2002-07-01  كشفت شركة مايكروسوفت للبرمجيات عن مشروع جديد ط...   ['واشنطن']
# 2002-07-01  ختم رونالدو مونديال 2002 في كوريا الجنوبية وال...   ['أمريكا']
# 2002-07-01  أكد مساعد وزير الخارجية الامريكى لشئون الشرق ا...      ['بوش']
# ...                                                       ...          ...
# 2014-05-26  26/مايو/2014]  صنعاء - سبأنت: ناقش اجتماع بمحا...  ['القاعدة']
# 2014-05-26  26/مايو/2014] زنجبار – سبأنت : أشاد محافظ أبين...  ['القاعدة']
# 2014-05-26  26/مايو/2014] أبين - سبأنت:  افتتح محافظ أبين ...  ['القاعدة']
# 2014-05-26  26/مايو/2014] باريس - سبأنت : احتفظت الأمريكية...      ['بوش']
# 2014-05-26  26/مايو/2014] صنعاء - سبأنت : نظم المجلس المحل...  ['القاعدة']
#
#                source text_label          text_score headline_label  \
# dateline
# 2002-07-01  SaudiYoum    neutral  0.9865078926086426        neutral
# 2002-07-01  SaudiYoum    neutral  0.8431360125541687        neutral
# 2002-07-01  SaudiYoum    neutral  0.9165139198303223       positive
# 2002-07-01  SaudiYoum    neutral  0.9760348002115885        neutral
# 2002-07-01  SaudiYoum    neutral  0.9650866985321045        neutral
# ...               ...        ...                 ...            ...
# 2014-05-26   Sabanews    neutral  0.9158061146736145        neutral
# 2014-05-26   Sabanews   positive  0.6742833852767944       positive
# 2014-05-26   Sabanews   positive      0.575439453125        neutral
# 2014-05-26   Sabanews    neutral  0.9725254774093628        neutral
# 2014-05-26   Sabanews   positive  0.8134450912475586        neutral
#
#             headline_score  text_label_as_int  headline_label_as_int  \
# dateline
# 2002-07-01        0.996348                  0                      0
# 2002-07-01        0.975554                  0                      0
# 2002-07-01        0.499695                  0                      1
# 2002-07-01        0.501716                  0                      0
# 2002-07-01        0.860890                  0                      0
# ...                    ...                ...                    ...
# 2014-05-26        0.992118                  0                      0
# 2014-05-26        0.832440                  1                      1
# 2014-05-26        0.719872                  1                      0
# 2014-05-26        0.621820                  0                      0
# 2014-05-26        0.702086                  1                      0
#
#             text_label_negative  text_label_neutral  text_label_positive
# dateline
# 2002-07-01                    0                   1                    0
# 2002-07-01                    0                   1                    0
# 2002-07-01                    0                   1                    0
# 2002-07-01                    0                   1                    0
# 2002-07-01                    0                   1                    0
# ...                         ...                 ...                  ...
# 2014-05-26                    0                   1                    0
# 2014-05-26                    0                   0                    1
# 2014-05-26                    0                   0                    1
# 2014-05-26                    0                   1                    0
# 2014-05-26                    0                   0                    1
#
# [16979 rows x 17 columns]

# %%
encoded
# Out:
#        index  Unnamed: 0               id  \
# 0          0      274890  TRN_ARB_0297955
# 2          2      274892  TRN_ARB_0297958
# 3          3      274893  TRN_ARB_0297960
# 4          4      274894  TRN_ARB_0297984
# 7          7      274897  TRN_ARB_0298010
# ...      ...         ...              ...
# 23556    351      121731  QBS_ARB_0250036
# 23557    352      121732  QBS_ARB_0250040
# 23559    354      121734  QBS_ARB_0250059
# 23560    355      121735  QBS_ARB_0250084
# 23561    356      121736  QBS_ARB_0250090
#
#                                                      url  \
# 0      http://tishreen.news.sy/tishreen/public/read/2...
# 2      http://tishreen.news.sy/tishreen/public/read/2...
# 3      http://tishreen.news.sy/tishreen/public/read/2...
# 4      http://tishreen.news.sy/tishreen/public/read/2...
# 7      http://tishreen.news.sy/tishreen/public/read/2...
# ...                                                  ...
# 23556             http://www.alqabas.com.kw/print/263733
# 23557             http://www.alqabas.com.kw/print/263738
# 23559             http://www.alqabas.com.kw/print/263757
# 23560             http://www.alqabas.com.kw/print/263784
# 23561             http://www.alqabas.com.kw/print/263792
#
#                                                 headline   dateline  \
# 0      وزير الخارجية الصيني: سنقوم بدور بنّاء وإيجابي... 2013-09-20
# 2      وزير الخارجية الإيراني: انضمام سورية لمعاهدة ح... 2013-09-20
# 3      استمرار أمريكا وحلفائها بدعم وتسليح الإرهابيين... 2013-09-20
# 4      المفاوض الفلسطيني.. والسباحة من جديد في بحر ال... 2013-09-22
# 7      المهندسة فهمية عروس: بالحوار نصـل بسـورية إلى ... 2013-09-22
# ...                                                  ...        ...
# 23556                       «القاعدة» يتبنّى هجمات العيد 2012-10-29
# 23557  بوتفليقة يبحث مع كلينتون تعزيز الشراكة الاقتصا... 2012-10-29
# 23559  العودة يدعو إلى الامتناع عن السفر إلى سوريا لل... 2012-10-29
# 23560              ميامي وليكرز أبرز المرشحين لنيل اللقب 2012-10-29
# 23561           اوباما يحذر مواطنيه من خطر الاعصار ساندي 2012-10-29
#
#                                                     text  \
# 0      \n20/09/2013\nوزير الخارجية الصيني: سنقوم بدور...
# 2      \n20/09/2013\nوزير الخارجية الإيراني: انضمام س...
# 3      \n20/09/2013\n«الخارجية» في رسالتين إلى رئيس م...
# 4      \n22/09/2013\nالمفاوض الفلسطيني.. والسباحة من ...
# 7      \n22/09/2013\nالمهندسة فهمية عروس: بالحوار نصـ...
# ...                                                  ...
# 23556  بغداد - وكالات - أعلنت امس ان قوات الامن العرا...
# 23557  (كونا) -- بحث الرئيس الجزائري عبدالعزيز بوتفلي...
# 23559  الرياض - يو بي آي - دعا عالم الدين السعودي، ال...
# 23560  واشنطن - أ ف ب - يشهد الموسم المقبل من الدوري ...
# 23561  (ا ف ب) - حذر الرئيس باراك اوباما الاثنين مواط...
#
#                                   tags    source text_label  \
# 0                           ['واشنطن']  Techreen    neutral
# 2                           ['واشنطن']  Techreen    neutral
# 3                ['أمريكا', 'القاعدة']  Techreen   negative
# 4                           ['واشنطن']  Techreen   negative
# 7                           ['أمريكا']  Techreen   positive
# ...                                ...       ...        ...
# 23556                      ['القاعدة']   Alqabas    neutral
# 23557  ['أمريكا', 'واشنطن', 'كلينتون']   Alqabas    neutral
# 23559                      ['القاعدة']   Alqabas    neutral
# 23560                ['واشنطن', 'بوش']   Alqabas    neutral
# 23561                       ['واشنطن']   Alqabas    neutral
#
#                text_score headline_label  headline_score  text_label_as_int  \
# 0      0.9574713706970215        neutral        0.538953                  0
# 2      0.5859406590461731        neutral        0.774108                  0
# 3      0.9461716612180074       negative        0.957832                 -1
# 4      0.9543005029360453       negative        0.954988                 -1
# 7      0.7322584191958109       positive        0.684957                  1
# ...                   ...            ...             ...                ...
# 23556  0.8499836921691895       negative        0.498749                  0
# 23557   0.990750253200531        neutral        0.994249                  0
# 23559  0.6828629374504089        neutral        0.902794                  0
# 23560  0.9449390172958374        neutral        0.904816                  0
# 23561  0.9412329792976379        neutral        0.825468                  0
#
#        headline_label_as_int  text_label_negative  text_label_neutral  \
# 0                          0                    0                   1
# 2                          0                    0                   1
# 3                         -1                    1                   0
# 4                         -1                    1                   0
# 7                          1                    0                   0
# ...                      ...                  ...                 ...
# 23556                     -1                    0                   1
# 23557                      0                    0                   1
# 23559                      0                    0                   1
# 23560                      0                    0                   1
# 23561                      0                    0                   1
#
#        text_label_positive
# 0                        0
# 2                        0
# 3                        0
# 4                        0
# 7                        1
# ...                    ...
# 23556                    0
# 23557                    0
# 23559                    0
# 23560                    0
# 23561                    0
#
# [16979 rows x 18 columns]

# %%
encoded = encoded.set_index('dateline').sort_index()

# %%
encoded
# Out:
#             index  Unnamed: 0               id  \
# dateline
# 2002-07-01    293      189146  SYM_ARB_0002704
# 2002-07-01    288      189141  SYM_ARB_0002614
# 2002-07-01    290      189143  SYM_ARB_0002644
# 2002-07-01    292      189145  SYM_ARB_0002684
# 2002-07-01    295      189148  SYM_ARB_0002732
# ...           ...         ...              ...
# 2014-05-26     84      188937  SBN_ARB_0092108
# 2014-05-26     83      188936  SBN_ARB_0092107
# 2014-05-26     82      188935  SBN_ARB_0092094
# 2014-05-26     79      188932  SBN_ARB_0092053
# 2014-05-26     81      188934  SBN_ARB_0092078
#
#                                                           url  \
# dateline
# 2002-07-01  http://www.alyaum.com/oldsite/issue/article.ph...
# 2002-07-01  http://www.alyaum.com/oldsite/issue/article.ph...
# 2002-07-01  http://www.alyaum.com/oldsite/issue/article.ph...
# 2002-07-01  http://www.alyaum.com/oldsite/issue/article.ph...
# 2002-07-01  http://www.alyaum.com/oldsite/issue/article.ph...
# ...                                                       ...
# 2014-05-26          http://www.sabanews.net/ar/news354901.htm
# 2014-05-26          http://www.sabanews.net/ar/news354899.htm
# 2014-05-26          http://www.sabanews.net/ar/news354885.htm
# 2014-05-26          http://www.sabanews.net/ar/news354841.htm
# 2014-05-26          http://www.sabanews.net/ar/news354868.htm
#
#                                                      headline  \
# dateline
# 2002-07-01  نائب خادم الحرمين الشريفين يستقبل عضوا في الكو...
# 2002-07-01                                        شروط العقار
# 2002-07-01                 ""بالاديوم"" لتحسين الأمن الحاسوبي
# 2002-07-01   رونالدو يقود السامبا للتحليق بكأس العالم الخامسة
# 2002-07-01  أمريكا تجري مشاورات مع الأصدقاء العرب لدفع عمل...
# ...                                                       ...
# 2014-05-26  وزير الداخلية يناقش مع قيادة محافظة صنعاء الأو...
# 2014-05-26  محافظ أبين يشيد بإنجاز فريق فحمان وصعوده للدور...
# 2014-05-26  افتتاح وتأسيس مشاريع تنموية وخدمية بأبين بتكلف...
# 2014-05-26  سيرينا تحتفظ بصدارة التصنيف العالمي للاعبات التنس
# 2014-05-26  مديريتا الوحدة والسبعين بأمانة العاصمة تحتفيان...
#
#                                                          text         tags  \
# dateline
# 2002-07-01  استقبل صاحب السمو الملكي الامير عبدالله بن عبد...   ['واشنطن']
# 2002-07-01  لايزال الاستثمار العقاري يعد من القنوات الاستث...  ['القاعدة']
# 2002-07-01  كشفت شركة مايكروسوفت للبرمجيات عن مشروع جديد ط...   ['واشنطن']
# 2002-07-01  ختم رونالدو مونديال 2002 في كوريا الجنوبية وال...   ['أمريكا']
# 2002-07-01  أكد مساعد وزير الخارجية الامريكى لشئون الشرق ا...      ['بوش']
# ...                                                       ...          ...
# 2014-05-26  26/مايو/2014]  صنعاء - سبأنت: ناقش اجتماع بمحا...  ['القاعدة']
# 2014-05-26  26/مايو/2014] زنجبار – سبأنت : أشاد محافظ أبين...  ['القاعدة']
# 2014-05-26  26/مايو/2014] أبين - سبأنت:  افتتح محافظ أبين ...  ['القاعدة']
# 2014-05-26  26/مايو/2014] باريس - سبأنت : احتفظت الأمريكية...      ['بوش']
# 2014-05-26  26/مايو/2014] صنعاء - سبأنت : نظم المجلس المحل...  ['القاعدة']
#
#                source text_label          text_score headline_label  \
# dateline
# 2002-07-01  SaudiYoum    neutral  0.9865078926086426        neutral
# 2002-07-01  SaudiYoum    neutral  0.8431360125541687        neutral
# 2002-07-01  SaudiYoum    neutral  0.9165139198303223       positive
# 2002-07-01  SaudiYoum    neutral  0.9760348002115885        neutral
# 2002-07-01  SaudiYoum    neutral  0.9650866985321045        neutral
# ...               ...        ...                 ...            ...
# 2014-05-26   Sabanews    neutral  0.9158061146736145        neutral
# 2014-05-26   Sabanews   positive  0.6742833852767944       positive
# 2014-05-26   Sabanews   positive      0.575439453125        neutral
# 2014-05-26   Sabanews    neutral  0.9725254774093628        neutral
# 2014-05-26   Sabanews   positive  0.8134450912475586        neutral
#
#             headline_score  text_label_as_int  headline_label_as_int  \
# dateline
# 2002-07-01        0.996348                  0                      0
# 2002-07-01        0.975554                  0                      0
# 2002-07-01        0.499695                  0                      1
# 2002-07-01        0.501716                  0                      0
# 2002-07-01        0.860890                  0                      0
# ...                    ...                ...                    ...
# 2014-05-26        0.992118                  0                      0
# 2014-05-26        0.832440                  1                      1
# 2014-05-26        0.719872                  1                      0
# 2014-05-26        0.621820                  0                      0
# 2014-05-26        0.702086                  1                      0
#
#             text_label_negative  text_label_neutral  text_label_positive
# dateline
# 2002-07-01                    0                   1                    0
# 2002-07-01                    0                   1                    0
# 2002-07-01                    0                   1                    0
# 2002-07-01                    0                   1                    0
# 2002-07-01                    0                   1                    0
# ...                         ...                 ...                  ...
# 2014-05-26                    0                   1                    0
# 2014-05-26                    0                   0                    1
# 2014-05-26                    0                   0                    1
# 2014-05-26                    0                   1                    0
# 2014-05-26                    0                   0                    1
#
# [16979 rows x 17 columns]

# %%
encoded.resample('1D').mean()
# Out:
#                  index     Unnamed: 0  headline_score  text_label_as_int  \
# dateline
# 2002-07-01  295.636364  189148.636364        0.831386          -0.181818
# 2002-07-02  310.750000  189163.750000        0.904175          -0.083333
# 2002-07-03  322.750000  189175.750000        0.833677           0.000000
# 2002-07-04   91.300000  188944.300000        0.818113           0.100000
# 2002-07-05  119.812500  188972.812500        0.848207          -0.062500
# ...                ...            ...             ...                ...
# 2014-05-22   62.000000  188915.000000        0.870710           0.000000
# 2014-05-23   67.000000  188920.000000        0.944024           0.000000
# 2014-05-24   71.500000  188924.500000        0.822392          -0.166667
# 2014-05-25   76.500000  188929.500000        0.835451           0.000000
# 2014-05-26   82.333333  188935.333333        0.774015           0.500000
#
#             headline_label_as_int  text_label_negative  text_label_neutral  \
# dateline
# 2002-07-01              -0.090909             0.181818            0.818182
# 2002-07-02              -0.250000             0.166667            0.750000
# 2002-07-03              -0.625000             0.125000            0.750000
# 2002-07-04              -0.200000             0.100000            0.700000
# 2002-07-05              -0.375000             0.250000            0.562500
# ...                           ...                  ...                 ...
# 2014-05-22               0.000000             0.285714            0.428571
# 2014-05-23              -0.333333             0.000000            1.000000
# 2014-05-24               0.000000             0.166667            0.833333
# 2014-05-25               0.000000             0.000000            1.000000
# 2014-05-26               0.166667             0.000000            0.500000
#
#             text_label_positive
# dateline
# 2002-07-01             0.000000
# 2002-07-02             0.083333
# 2002-07-03             0.125000
# 2002-07-04             0.200000
# 2002-07-05             0.187500
# ...                         ...
# 2014-05-22             0.285714
# 2014-05-23             0.000000
# 2014-05-24             0.000000
# 2014-05-25             0.000000
# 2014-05-26             0.500000
#
# [4348 rows x 8 columns]

# %%
sns.lineplot(data = encoded.resample('1M').mean(), x = 'dateline', y = 'text_label_negative')
sns.lineplot(data = encoded.resample('1M').mean(), x = 'dateline', y = 'text_label_neutral')
sns.lineplot(data = encoded.resample('1M').mean(), x = 'dateline', y = 'text_label_positive')
# Out:
# <AxesSubplot:xlabel='dateline', ylabel='text_label_negative'>

# %%
import datetime as dt
plt.figure(figsize = (12, 8))
sns.lineplot(data = encoded.resample('1M').sum(), x = 'dateline', y = 'text_label_negative')
sns.lineplot(data = encoded.resample('1M').sum(), x = 'dateline', y = 'text_label_neutral')
sns.lineplot(data = encoded.resample('1M').sum(), x = 'dateline', y = 'text_label_positive', label = 'positive')
plt.axvline(dt.datetime(2008, 11, 1)) # (something happened)
plt.axvline(dt.datetime(2004, 11, 1)) # (something happened)
plt.axvline(dt.datetime(2012, 9, 21)) # (something happened)
plt.text(dt.datetime(2008, 11, 5),500,'election',rotation=90)
plt.text(dt.datetime(2004, 11, 5),500,'election',rotation=90)
plt.text(dt.datetime(2012, 11, 5),500,'election',rotation=90)
plt.legend()

# %%
def country_tagger(df):
    country_map = { 'Alittihad': 'emirates',
                    'Echoroukonline': 'algeria',
                    'Ryiadh': 'ksa',
                    'SaudiYoum': 'ksa',
                    'Techreen': 'syria',
                    'Alqabas': 'kuwait',
                    'Almustaqbal': 'lebanon',
                    'Almasryalyoum': 'egypt',
                    'Youm7': 'egypt',
                    'Sabanews': 'yemen',
                    }
    df['country'] = df.source.map(country_map)
    return df

# %%
country_tagger(encoded)
# Out:
#             index  Unnamed: 0               id  \
# dateline
# 2002-07-01    293      189146  SYM_ARB_0002704
# 2002-07-01    288      189141  SYM_ARB_0002614
# 2002-07-01    290      189143  SYM_ARB_0002644
# 2002-07-01    292      189145  SYM_ARB_0002684
# 2002-07-01    295      189148  SYM_ARB_0002732
# ...           ...         ...              ...
# 2014-05-26     84      188937  SBN_ARB_0092108
# 2014-05-26     83      188936  SBN_ARB_0092107
# 2014-05-26     82      188935  SBN_ARB_0092094
# 2014-05-26     79      188932  SBN_ARB_0092053
# 2014-05-26     81      188934  SBN_ARB_0092078
#
#                                                           url  \
# dateline
# 2002-07-01  http://www.alyaum.com/oldsite/issue/article.ph...
# 2002-07-01  http://www.alyaum.com/oldsite/issue/article.ph...
# 2002-07-01  http://www.alyaum.com/oldsite/issue/article.ph...
# 2002-07-01  http://www.alyaum.com/oldsite/issue/article.ph...
# 2002-07-01  http://www.alyaum.com/oldsite/issue/article.ph...
# ...                                                       ...
# 2014-05-26          http://www.sabanews.net/ar/news354901.htm
# 2014-05-26          http://www.sabanews.net/ar/news354899.htm
# 2014-05-26          http://www.sabanews.net/ar/news354885.htm
# 2014-05-26          http://www.sabanews.net/ar/news354841.htm
# 2014-05-26          http://www.sabanews.net/ar/news354868.htm
#
#                                                      headline  \
# dateline
# 2002-07-01  نائب خادم الحرمين الشريفين يستقبل عضوا في الكو...
# 2002-07-01                                        شروط العقار
# 2002-07-01                 ""بالاديوم"" لتحسين الأمن الحاسوبي
# 2002-07-01   رونالدو يقود السامبا للتحليق بكأس العالم الخامسة
# 2002-07-01  أمريكا تجري مشاورات مع الأصدقاء العرب لدفع عمل...
# ...                                                       ...
# 2014-05-26  وزير الداخلية يناقش مع قيادة محافظة صنعاء الأو...
# 2014-05-26  محافظ أبين يشيد بإنجاز فريق فحمان وصعوده للدور...
# 2014-05-26  افتتاح وتأسيس مشاريع تنموية وخدمية بأبين بتكلف...
# 2014-05-26  سيرينا تحتفظ بصدارة التصنيف العالمي للاعبات التنس
# 2014-05-26  مديريتا الوحدة والسبعين بأمانة العاصمة تحتفيان...
#
#                                                          text         tags  \
# dateline
# 2002-07-01  استقبل صاحب السمو الملكي الامير عبدالله بن عبد...   ['واشنطن']
# 2002-07-01  لايزال الاستثمار العقاري يعد من القنوات الاستث...  ['القاعدة']
# 2002-07-01  كشفت شركة مايكروسوفت للبرمجيات عن مشروع جديد ط...   ['واشنطن']
# 2002-07-01  ختم رونالدو مونديال 2002 في كوريا الجنوبية وال...   ['أمريكا']
# 2002-07-01  أكد مساعد وزير الخارجية الامريكى لشئون الشرق ا...      ['بوش']
# ...                                                       ...          ...
# 2014-05-26  26/مايو/2014]  صنعاء - سبأنت: ناقش اجتماع بمحا...  ['القاعدة']
# 2014-05-26  26/مايو/2014] زنجبار – سبأنت : أشاد محافظ أبين...  ['القاعدة']
# 2014-05-26  26/مايو/2014] أبين - سبأنت:  افتتح محافظ أبين ...  ['القاعدة']
# 2014-05-26  26/مايو/2014] باريس - سبأنت : احتفظت الأمريكية...      ['بوش']
# 2014-05-26  26/مايو/2014] صنعاء - سبأنت : نظم المجلس المحل...  ['القاعدة']
#
#                source text_label          text_score headline_label  \
# dateline
# 2002-07-01  SaudiYoum    neutral  0.9865078926086426        neutral
# 2002-07-01  SaudiYoum    neutral  0.8431360125541687        neutral
# 2002-07-01  SaudiYoum    neutral  0.9165139198303223       positive
# 2002-07-01  SaudiYoum    neutral  0.9760348002115885        neutral
# 2002-07-01  SaudiYoum    neutral  0.9650866985321045        neutral
# ...               ...        ...                 ...            ...
# 2014-05-26   Sabanews    neutral  0.9158061146736145        neutral
# 2014-05-26   Sabanews   positive  0.6742833852767944       positive
# 2014-05-26   Sabanews   positive      0.575439453125        neutral
# 2014-05-26   Sabanews    neutral  0.9725254774093628        neutral
# 2014-05-26   Sabanews   positive  0.8134450912475586        neutral
#
#             headline_score  text_label_as_int  headline_label_as_int  \
# dateline
# 2002-07-01        0.996348                  0                      0
# 2002-07-01        0.975554                  0                      0
# 2002-07-01        0.499695                  0                      1
# 2002-07-01        0.501716                  0                      0
# 2002-07-01        0.860890                  0                      0
# ...                    ...                ...                    ...
# 2014-05-26        0.992118                  0                      0
# 2014-05-26        0.832440                  1                      1
# 2014-05-26        0.719872                  1                      0
# 2014-05-26        0.621820                  0                      0
# 2014-05-26        0.702086                  1                      0
#
#             text_label_negative  text_label_neutral  text_label_positive  \
# dateline
# 2002-07-01                    0                   1                    0
# 2002-07-01                    0                   1                    0
# 2002-07-01                    0                   1                    0
# 2002-07-01                    0                   1                    0
# 2002-07-01                    0                   1                    0
# ...                         ...                 ...                  ...
# 2014-05-26                    0                   1                    0
# 2014-05-26                    0                   0                    1
# 2014-05-26                    0                   0                    1
# 2014-05-26                    0                   1                    0
# 2014-05-26                    0                   0                    1
#
#            country
# dateline
# 2002-07-01     ksa
# 2002-07-01     ksa
# 2002-07-01     ksa
# 2002-07-01     ksa
# 2002-07-01     ksa
# ...            ...
# 2014-05-26   yemen
# 2014-05-26   yemen
# 2014-05-26   yemen
# 2014-05-26   yemen
# 2014-05-26   yemen
#
# [16979 rows x 18 columns]

# %%
encoded.country.value_counts()
# Out:
# egypt       4660
# ksa         3857
# syria       2083
# lebanon     1870
# emirates    1680
# kuwait      1463
# yemen       1089
# algeria      277
# Name: country, dtype: int64

# %%
encoded
# Out:
#             index  Unnamed: 0               id  \
# dateline
# 2002-07-01    293      189146  SYM_ARB_0002704
# 2002-07-01    288      189141  SYM_ARB_0002614
# 2002-07-01    290      189143  SYM_ARB_0002644
# 2002-07-01    292      189145  SYM_ARB_0002684
# 2002-07-01    295      189148  SYM_ARB_0002732
# ...           ...         ...              ...
# 2014-05-26     84      188937  SBN_ARB_0092108
# 2014-05-26     83      188936  SBN_ARB_0092107
# 2014-05-26     82      188935  SBN_ARB_0092094
# 2014-05-26     79      188932  SBN_ARB_0092053
# 2014-05-26     81      188934  SBN_ARB_0092078
#
#                                                           url  \
# dateline
# 2002-07-01  http://www.alyaum.com/oldsite/issue/article.ph...
# 2002-07-01  http://www.alyaum.com/oldsite/issue/article.ph...
# 2002-07-01  http://www.alyaum.com/oldsite/issue/article.ph...
# 2002-07-01  http://www.alyaum.com/oldsite/issue/article.ph...
# 2002-07-01  http://www.alyaum.com/oldsite/issue/article.ph...
# ...                                                       ...
# 2014-05-26          http://www.sabanews.net/ar/news354901.htm
# 2014-05-26          http://www.sabanews.net/ar/news354899.htm
# 2014-05-26          http://www.sabanews.net/ar/news354885.htm
# 2014-05-26          http://www.sabanews.net/ar/news354841.htm
# 2014-05-26          http://www.sabanews.net/ar/news354868.htm
#
#                                                      headline  \
# dateline
# 2002-07-01  نائب خادم الحرمين الشريفين يستقبل عضوا في الكو...
# 2002-07-01                                        شروط العقار
# 2002-07-01                 ""بالاديوم"" لتحسين الأمن الحاسوبي
# 2002-07-01   رونالدو يقود السامبا للتحليق بكأس العالم الخامسة
# 2002-07-01  أمريكا تجري مشاورات مع الأصدقاء العرب لدفع عمل...
# ...                                                       ...
# 2014-05-26  وزير الداخلية يناقش مع قيادة محافظة صنعاء الأو...
# 2014-05-26  محافظ أبين يشيد بإنجاز فريق فحمان وصعوده للدور...
# 2014-05-26  افتتاح وتأسيس مشاريع تنموية وخدمية بأبين بتكلف...
# 2014-05-26  سيرينا تحتفظ بصدارة التصنيف العالمي للاعبات التنس
# 2014-05-26  مديريتا الوحدة والسبعين بأمانة العاصمة تحتفيان...
#
#                                                          text         tags  \
# dateline
# 2002-07-01  استقبل صاحب السمو الملكي الامير عبدالله بن عبد...   ['واشنطن']
# 2002-07-01  لايزال الاستثمار العقاري يعد من القنوات الاستث...  ['القاعدة']
# 2002-07-01  كشفت شركة مايكروسوفت للبرمجيات عن مشروع جديد ط...   ['واشنطن']
# 2002-07-01  ختم رونالدو مونديال 2002 في كوريا الجنوبية وال...   ['أمريكا']
# 2002-07-01  أكد مساعد وزير الخارجية الامريكى لشئون الشرق ا...      ['بوش']
# ...                                                       ...          ...
# 2014-05-26  26/مايو/2014]  صنعاء - سبأنت: ناقش اجتماع بمحا...  ['القاعدة']
# 2014-05-26  26/مايو/2014] زنجبار – سبأنت : أشاد محافظ أبين...  ['القاعدة']
# 2014-05-26  26/مايو/2014] أبين - سبأنت:  افتتح محافظ أبين ...  ['القاعدة']
# 2014-05-26  26/مايو/2014] باريس - سبأنت : احتفظت الأمريكية...      ['بوش']
# 2014-05-26  26/مايو/2014] صنعاء - سبأنت : نظم المجلس المحل...  ['القاعدة']
#
#                source text_label          text_score headline_label  \
# dateline
# 2002-07-01  SaudiYoum    neutral  0.9865078926086426        neutral
# 2002-07-01  SaudiYoum    neutral  0.8431360125541687        neutral
# 2002-07-01  SaudiYoum    neutral  0.9165139198303223       positive
# 2002-07-01  SaudiYoum    neutral  0.9760348002115885        neutral
# 2002-07-01  SaudiYoum    neutral  0.9650866985321045        neutral
# ...               ...        ...                 ...            ...
# 2014-05-26   Sabanews    neutral  0.9158061146736145        neutral
# 2014-05-26   Sabanews   positive  0.6742833852767944       positive
# 2014-05-26   Sabanews   positive      0.575439453125        neutral
# 2014-05-26   Sabanews    neutral  0.9725254774093628        neutral
# 2014-05-26   Sabanews   positive  0.8134450912475586        neutral
#
#             headline_score  text_label_as_int  headline_label_as_int  \
# dateline
# 2002-07-01        0.996348                  0                      0
# 2002-07-01        0.975554                  0                      0
# 2002-07-01        0.499695                  0                      1
# 2002-07-01        0.501716                  0                      0
# 2002-07-01        0.860890                  0                      0
# ...                    ...                ...                    ...
# 2014-05-26        0.992118                  0                      0
# 2014-05-26        0.832440                  1                      1
# 2014-05-26        0.719872                  1                      0
# 2014-05-26        0.621820                  0                      0
# 2014-05-26        0.702086                  1                      0
#
#             text_label_negative  text_label_neutral  text_label_positive  \
# dateline
# 2002-07-01                    0                   1                    0
# 2002-07-01                    0                   1                    0
# 2002-07-01                    0                   1                    0
# 2002-07-01                    0                   1                    0
# 2002-07-01                    0                   1                    0
# ...                         ...                 ...                  ...
# 2014-05-26                    0                   1                    0
# 2014-05-26                    0                   0                    1
# 2014-05-26                    0                   0                    1
# 2014-05-26                    0                   1                    0
# 2014-05-26                    0                   0                    1
#
#            country
# dateline
# 2002-07-01     ksa
# 2002-07-01     ksa
# 2002-07-01     ksa
# 2002-07-01     ksa
# 2002-07-01     ksa
# ...            ...
# 2014-05-26   yemen
# 2014-05-26   yemen
# 2014-05-26   yemen
# 2014-05-26   yemen
# 2014-05-26   yemen
#
# [16979 rows x 18 columns]

# %% [markdown]
# # Hypothesis testing

# %% [markdown]
# $H_{0}$: Calculated article sentiment is independant of calculated headline sentiment
#
# $H_{a}$: Calculated article sentiment is NOT independant of calculated headline sentiment

# %%
alpha = .05
observed = pd.crosstab(encoded.text_label, encoded.headline_label)
observed
# Out:
# headline_label  negative  neutral  positive
# text_label
# negative            2003     1784       184
# neutral             1602    10139       568
# positive              24      373       302

# %%
from scipy import stats
chi2, p, degf, expected = stats.chi2_contingency(observed)

# %%
chi2, p
# Out:
# (4302.6845414551235, 0.0)

# %%
pd.DataFrame(expected)
# Out:
#              0            1           2
# 0   848.740150  2875.753342  246.506508
# 1  2630.859356  8914.038754  764.101891
# 2   149.400495   506.207904   43.391601

# %%
p < alpha
# Out:
# True

# %% [markdown]
# Because p is less than alpha we can reject the Null Hypothesis and determine that calculated article sentiment is NOT independant of calculated headline sentiment.

# %%
encoded.resample('1M').mean()
# Out:
#                  index     Unnamed: 0  headline_score  text_label_as_int  \
# dateline
# 2002-07-31  219.005376  189072.005376        0.875436          -0.102151
# 2002-08-31         NaN            NaN             NaN                NaN
# 2002-09-30         NaN            NaN             NaN                NaN
# 2002-10-31         NaN            NaN             NaN                NaN
# 2002-11-30  344.000000  150284.000000        0.899981          -0.846154
# ...                ...            ...             ...                ...
# 2014-01-31  255.973451   26316.973451        0.842267          -0.061947
# 2014-02-28  166.402256  130828.402256        0.847068          -0.135338
# 2014-03-31  180.171821  131188.130584        0.849150          -0.168385
# 2014-04-30         NaN            NaN             NaN                NaN
# 2014-05-31   43.538462  188896.538462        0.851242           0.076923
#
#             headline_label_as_int  text_label_negative  text_label_neutral  \
# dateline
# 2002-07-31              -0.172043             0.193548            0.715054
# 2002-08-31                    NaN                  NaN                 NaN
# 2002-09-30                    NaN                  NaN                 NaN
# 2002-10-31                    NaN                  NaN                 NaN
# 2002-11-30              -0.076923             0.846154            0.153846
# ...                           ...                  ...                 ...
# 2014-01-31              -0.106195             0.115044            0.831858
# 2014-02-28              -0.154135             0.172932            0.789474
# 2014-03-31              -0.134021             0.216495            0.735395
# 2014-04-30                    NaN                  NaN                 NaN
# 2014-05-31               0.025641             0.076923            0.769231
#
#             text_label_positive
# dateline
# 2002-07-31             0.091398
# 2002-08-31                  NaN
# 2002-09-30                  NaN
# 2002-10-31                  NaN
# 2002-11-30             0.000000
# ...                         ...
# 2014-01-31             0.053097
# 2014-02-28             0.037594
# 2014-03-31             0.048110
# 2014-04-30                  NaN
# 2014-05-31             0.153846
#
# [143 rows x 8 columns]

# %%
sns.lineplot(data = encoded.resample('1D').sum(), x = 'dateline', y= 'text_label_as_int')
# Out:
# <AxesSubplot:xlabel='dateline', ylabel='text_label_as_int'>

# %%
sns.lineplot(data = encoded.resample('1D').sum(), x = 'dateline', y= 'headline_label_as_int')
# Out:
# <AxesSubplot:xlabel='dateline', ylabel='headline_label_as_int'>

# %%
encoded
# Out:
#             index  Unnamed: 0               id  \
# dateline
# 2002-07-01    293      189146  SYM_ARB_0002704
# 2002-07-01    288      189141  SYM_ARB_0002614
# 2002-07-01    290      189143  SYM_ARB_0002644
# 2002-07-01    292      189145  SYM_ARB_0002684
# 2002-07-01    295      189148  SYM_ARB_0002732
# ...           ...         ...              ...
# 2014-05-26     84      188937  SBN_ARB_0092108
# 2014-05-26     83      188936  SBN_ARB_0092107
# 2014-05-26     82      188935  SBN_ARB_0092094
# 2014-05-26     79      188932  SBN_ARB_0092053
# 2014-05-26     81      188934  SBN_ARB_0092078
#
#                                                           url  \
# dateline
# 2002-07-01  http://www.alyaum.com/oldsite/issue/article.ph...
# 2002-07-01  http://www.alyaum.com/oldsite/issue/article.ph...
# 2002-07-01  http://www.alyaum.com/oldsite/issue/article.ph...
# 2002-07-01  http://www.alyaum.com/oldsite/issue/article.ph...
# 2002-07-01  http://www.alyaum.com/oldsite/issue/article.ph...
# ...                                                       ...
# 2014-05-26          http://www.sabanews.net/ar/news354901.htm
# 2014-05-26          http://www.sabanews.net/ar/news354899.htm
# 2014-05-26          http://www.sabanews.net/ar/news354885.htm
# 2014-05-26          http://www.sabanews.net/ar/news354841.htm
# 2014-05-26          http://www.sabanews.net/ar/news354868.htm
#
#                                                      headline  \
# dateline
# 2002-07-01  نائب خادم الحرمين الشريفين يستقبل عضوا في الكو...
# 2002-07-01                                        شروط العقار
# 2002-07-01                 ""بالاديوم"" لتحسين الأمن الحاسوبي
# 2002-07-01   رونالدو يقود السامبا للتحليق بكأس العالم الخامسة
# 2002-07-01  أمريكا تجري مشاورات مع الأصدقاء العرب لدفع عمل...
# ...                                                       ...
# 2014-05-26  وزير الداخلية يناقش مع قيادة محافظة صنعاء الأو...
# 2014-05-26  محافظ أبين يشيد بإنجاز فريق فحمان وصعوده للدور...
# 2014-05-26  افتتاح وتأسيس مشاريع تنموية وخدمية بأبين بتكلف...
# 2014-05-26  سيرينا تحتفظ بصدارة التصنيف العالمي للاعبات التنس
# 2014-05-26  مديريتا الوحدة والسبعين بأمانة العاصمة تحتفيان...
#
#                                                          text         tags  \
# dateline
# 2002-07-01  استقبل صاحب السمو الملكي الامير عبدالله بن عبد...   ['واشنطن']
# 2002-07-01  لايزال الاستثمار العقاري يعد من القنوات الاستث...  ['القاعدة']
# 2002-07-01  كشفت شركة مايكروسوفت للبرمجيات عن مشروع جديد ط...   ['واشنطن']
# 2002-07-01  ختم رونالدو مونديال 2002 في كوريا الجنوبية وال...   ['أمريكا']
# 2002-07-01  أكد مساعد وزير الخارجية الامريكى لشئون الشرق ا...      ['بوش']
# ...                                                       ...          ...
# 2014-05-26  26/مايو/2014]  صنعاء - سبأنت: ناقش اجتماع بمحا...  ['القاعدة']
# 2014-05-26  26/مايو/2014] زنجبار – سبأنت : أشاد محافظ أبين...  ['القاعدة']
# 2014-05-26  26/مايو/2014] أبين - سبأنت:  افتتح محافظ أبين ...  ['القاعدة']
# 2014-05-26  26/مايو/2014] باريس - سبأنت : احتفظت الأمريكية...      ['بوش']
# 2014-05-26  26/مايو/2014] صنعاء - سبأنت : نظم المجلس المحل...  ['القاعدة']
#
#                source text_label          text_score headline_label  \
# dateline
# 2002-07-01  SaudiYoum    neutral  0.9865078926086426        neutral
# 2002-07-01  SaudiYoum    neutral  0.8431360125541687        neutral
# 2002-07-01  SaudiYoum    neutral  0.9165139198303223       positive
# 2002-07-01  SaudiYoum    neutral  0.9760348002115885        neutral
# 2002-07-01  SaudiYoum    neutral  0.9650866985321045        neutral
# ...               ...        ...                 ...            ...
# 2014-05-26   Sabanews    neutral  0.9158061146736145        neutral
# 2014-05-26   Sabanews   positive  0.6742833852767944       positive
# 2014-05-26   Sabanews   positive      0.575439453125        neutral
# 2014-05-26   Sabanews    neutral  0.9725254774093628        neutral
# 2014-05-26   Sabanews   positive  0.8134450912475586        neutral
#
#             headline_score  text_label_as_int  headline_label_as_int  \
# dateline
# 2002-07-01        0.996348                  0                      0
# 2002-07-01        0.975554                  0                      0
# 2002-07-01        0.499695                  0                      1
# 2002-07-01        0.501716                  0                      0
# 2002-07-01        0.860890                  0                      0
# ...                    ...                ...                    ...
# 2014-05-26        0.992118                  0                      0
# 2014-05-26        0.832440                  1                      1
# 2014-05-26        0.719872                  1                      0
# 2014-05-26        0.621820                  0                      0
# 2014-05-26        0.702086                  1                      0
#
#             text_label_negative  text_label_neutral  text_label_positive  \
# dateline
# 2002-07-01                    0                   1                    0
# 2002-07-01                    0                   1                    0
# 2002-07-01                    0                   1                    0
# 2002-07-01                    0                   1                    0
# 2002-07-01                    0                   1                    0
# ...                         ...                 ...                  ...
# 2014-05-26                    0                   1                    0
# 2014-05-26                    0                   0                    1
# 2014-05-26                    0                   0                    1
# 2014-05-26                    0                   1                    0
# 2014-05-26                    0                   0                    1
#
#            country
# dateline
# 2002-07-01     ksa
# 2002-07-01     ksa
# 2002-07-01     ksa
# 2002-07-01     ksa
# 2002-07-01     ksa
# ...            ...
# 2014-05-26   yemen
# 2014-05-26   yemen
# 2014-05-26   yemen
# 2014-05-26   yemen
# 2014-05-26   yemen
#
# [16979 rows x 18 columns]

# %%
encoded[(encoded.index >= '2006-01-01') & (encoded.index <= '2007-01-01')]
# Out:
#             index  Unnamed: 0               id  \
# dateline
# 2006-01-02    209      103739  QBS_ARB_0000357
# 2006-01-02    187      103717  QBS_ARB_0000089
# 2006-01-02    191      103721  QBS_ARB_0000167
# 2006-01-02    192      103722  QBS_ARB_0000174
# 2006-01-02    193      103723  QBS_ARB_0000179
# ...           ...         ...              ...
# 2006-04-03    200      155138  RYD_ARB_0055156
# 2006-04-28    243      158751  RYD_ARB_0101350
# 2006-04-28    240      158748  RYD_ARB_0101345
# 2006-04-28    237      158745  RYD_ARB_0101285
# 2006-04-28    236      158744  RYD_ARB_0101259
#
#                                                           url  \
# dateline
# 2006-01-02             http://www.alqabas.com.kw/print/114748
# 2006-01-02             http://www.alqabas.com.kw/print/114474
# 2006-01-02             http://www.alqabas.com.kw/print/114552
# 2006-01-02             http://www.alqabas.com.kw/print/114560
# 2006-01-02             http://www.alqabas.com.kw/print/114565
# ...                                                       ...
# 2006-04-03  http://www.alriyadh.com/2006/04/03/article1432...
# 2006-04-28  http://www.alriyadh.com/2006/04/28/article1498...
# 2006-04-28  http://www.alriyadh.com/2006/04/28/article1498...
# 2006-04-28  http://www.alriyadh.com/2006/04/28/article1497...
# 2006-04-28  http://www.alriyadh.com/2006/04/28/article1497...
#
#                                                      headline  \
# dateline
# 2006-01-02  الـجزائر: اعتقال ممثل تنظيم القاعدة في افريقيا...
# 2006-01-02                      أميركا العلمانية تحارب الشعوب
# 2006-01-02  المخابرات الأميركية: 10 سنوات لإعادة بناء الخد...
# 2006-01-02  مقتل 20 عراقيا بينهم طفلان والعثور على 8 جثث ف...
# 2006-01-02              أموال أميركية لإقناع السنة بنبذ العنف
# ...                                                       ...
# 2006-04-03    الاتحاد يستضيف الأنصار.. والأهلي يخوض تحدي أُحد
# 2006-04-28  صالح الثبيتي.. أول قارئ نشرة أخبار سعودي على ش...
# 2006-04-28  6 فتيات موهوبات في إذاعة جدة يدعمن مسيرة المرأ...
# 2006-04-28          اتفاقية تجارية بين بوليفيا وكوبا وفنزويلا
# 2006-04-28      اتفاق بين تشاد والبنك الدولي حول عائدات النفط
#
#                                                          text  \
# dateline
# 2006-01-02  القاهرة، الجزائر - د.ب.أ - ذكرت احدى الصحف الج...
# 2006-01-02  بقلم: عيد الدويهيس\nثبت ان أغلبية الشباب المسل...
# 2006-01-02  واشنطن - رويترز - يقول ضابط سابق في قسم مكافحة...
# 2006-01-02  بغداد، بعقوبة، كركوك، الموصل - أِفِب، رويترز، ...
# 2006-01-02  نيويورك - رويترز - قالت نيويورك تايمز امس ان ش...
# ...                                                       ...
# 2006-04-03  كتب - صالح الحبيشي:\nفي اليوم الخامس لمنافسات ...
# 2006-04-28  الرياض - ممدوح المهيني:\nسيصبح المذيع السعودي ...
# 2006-04-28  جدة - منى الحيدري:\nعندما نتحدث عن انجازات للم...
# 2006-04-28  لاباز - واس:\nصرح رئيس بوليفيا إيفو موراليس ال...
# 2006-04-28  واشنطن - (ا ف ب):\nاعلن البنك الدولي في بيان أ...
#
#                                tags   source text_label          text_score  \
# dateline
# 2006-01-02              ['القاعدة']  Alqabas    neutral  0.6352986097335815
# 2006-01-02              ['القاعدة']  Alqabas   negative  0.9769048690795898
# 2006-01-02  ['واشنطن', '11 سبتمبر']  Alqabas    neutral  0.9612250328063965
# 2006-01-02              ['القاعدة']  Alqabas    neutral  0.7748285929361979
# 2006-01-02               ['واشنطن']  Alqabas    neutral  0.9450510740280151
# ...                             ...      ...        ...                 ...
# 2006-04-03               ['أمريكا']   Ryiadh    neutral     0.9851114153862
# 2006-04-28               ['أمريكا']   Ryiadh   positive  0.7087415456771851
# 2006-04-28               ['واشنطن']   Ryiadh   positive  0.8457128802935282
# 2006-04-28               ['أمريكا']   Ryiadh    neutral   0.984672486782074
# 2006-04-28               ['واشنطن']   Ryiadh    neutral  0.9570521712303162
#
#            headline_label  headline_score  text_label_as_int  \
# dateline
# 2006-01-02        neutral        0.979953                  0
# 2006-01-02       negative        0.992120                 -1
# 2006-01-02        neutral        0.975905                  0
# 2006-01-02       negative        0.867741                  0
# 2006-01-02        neutral        0.931798                  0
# ...                   ...             ...                ...
# 2006-04-03        neutral        0.986218                  0
# 2006-04-28        neutral        0.959711                  1
# 2006-04-28       positive        0.800169                  1
# 2006-04-28        neutral        0.987599                  0
# 2006-04-28        neutral        0.989039                  0
#
#             headline_label_as_int  text_label_negative  text_label_neutral  \
# dateline
# 2006-01-02                      0                    0                   1
# 2006-01-02                     -1                    1                   0
# 2006-01-02                      0                    0                   1
# 2006-01-02                     -1                    0                   1
# 2006-01-02                      0                    0                   1
# ...                           ...                  ...                 ...
# 2006-04-03                      0                    0                   1
# 2006-04-28                      0                    0                   0
# 2006-04-28                      1                    0                   0
# 2006-04-28                      0                    0                   1
# 2006-04-28                      0                    0                   1
#
#             text_label_positive country
# dateline
# 2006-01-02                    0  kuwait
# 2006-01-02                    0  kuwait
# 2006-01-02                    0  kuwait
# 2006-01-02                    0  kuwait
# 2006-01-02                    0  kuwait
# ...                         ...     ...
# 2006-04-03                    0     ksa
# 2006-04-28                    1     ksa
# 2006-04-28                    1     ksa
# 2006-04-28                    0     ksa
# 2006-04-28                    0     ksa
#
# [350 rows x 18 columns]

# %%
sns.lineplot(data = encoded[(encoded.index >= '2006-01-01') & (encoded.index <= '2007-01-01')].resample(1D).sum(), x = 'dateline', y = 'text_label_negative')
# Out:
#   File "/var/folders/r6/g880v64s6vj401drwcc37nf00000gn/T/ipykernel_43830/2483660266.py", line 1
#     sns.lineplot(data = encoded[(encoded.index >= '2006-01-01') & (encoded.index <= '2007-01-01')].resample(1D).sum(), x = 'dateline', y = 'text_label_negative')
#                                                                                                              ^
# SyntaxError: invalid syntax

# %%
no_false = new[new.text_label != 'False']
